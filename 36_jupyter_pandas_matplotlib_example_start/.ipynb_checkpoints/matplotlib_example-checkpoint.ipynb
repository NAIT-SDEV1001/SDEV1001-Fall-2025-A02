# %%
# install pandas 
import pandas as pd
# install matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv')

data.head()
# Out:
# C:\Users\dmouris\AppData\Local\Temp\ipykernel_19640\3923736313.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/Property_Assessment_Data_(Current_Calendar_Year)_20251030.csv')
#    Account Number Suite  House Number           Street Name  Neighbourhood ID  \
# 0         4058129   NaN         870.0  ABBOTTSFIELD ROAD NW            2010.0
# 1         4058137   NaN         872.0  ABBOTTSFIELD ROAD NW            2010.0
# 2         4058145   NaN         874.0  ABBOTTSFIELD ROAD NW            2010.0
# 3         4058152   NaN         876.0  ABBOTTSFIELD ROAD NW            2010.0
# 4         4058160   NaN         878.0  ABBOTTSFIELD ROAD NW            2010.0
#
#   Neighbourhood   Ward  Assessed Value    Tax Class Garage Assessment Class 1  \
# 0  ABBOTTSFIELD  Métis          150000  Residential      N        RESIDENTIAL
# 1  ABBOTTSFIELD  Métis          149500  Residential      N        RESIDENTIAL
# 2  ABBOTTSFIELD  Métis          151500  Residential      N        RESIDENTIAL
# 3  ABBOTTSFIELD  Métis          147000  Residential      N        RESIDENTIAL
# 4  ABBOTTSFIELD  Métis          153500  Residential      N        RESIDENTIAL
#
#   Assessment Class 2 Assessment Class 3  Assessment Class % 1  \
# 0                NaN                NaN                   100
# 1                NaN                NaN                   100
# 2                NaN                NaN                   100
# 3                NaN                NaN                   100
# 4                NaN                NaN                   100
#
#    Assessment Class % 2  Assessment Class % 3   Latitude   Longitude  \
# 0                   NaN                   NaN  53.576329 -113.392304
# 1                   NaN                   NaN  53.576329 -113.392304
# 2                   NaN                   NaN  53.576329 -113.392304
# 3                   NaN                   NaN  53.576329 -113.392304
# 4                   NaN                   NaN  53.576329 -113.392304
#
#                                   Point Location
# 0  POINT (-113.39230350026378 53.57632901357068)
# 1  POINT (-113.39230350026378 53.57632901357068)
# 2  POINT (-113.39230350026378 53.57632901357068)
# 3  POINT (-113.39230350026378 53.57632901357068)
# 4  POINT (-113.39230350026378 53.57632901357068)

# %%
residential_data = data[data["Tax Class"] == "Residential"]

residential_data.shape
# Out:
# (403864, 19)

# %%
houses_only = data[data["Assessment Class 1"] == "RESIDENTIAL"]


houses_only = houses_only[houses_only["Assessment Class 2"] == "RESIDENTIAL"].sort_values(by="Assessed Value", ascending=False)
houses_only = houses_only[houses_only["Assessment Class 3"] == "RESIDENTIAL"].sort_values(by="Assessed Value", ascending=False)

top_6_most_expensive = houses_only.sort_values(by="Assessed Value", ascending=False)[:6]
# sort values sorts
# the [:6] you can "chain" this together to get the first 6 values

# let's take a look at the top 10 in top_6_most_expensive (there's only 6) 
top_6_most_expensive.head(10)
# as a reminder head is a "viewing function" it's going show the first 10 but if there's only 6 it'll show 6
# Out:
# Empty DataFrame
# Columns: [Account Number, Suite, House Number, Street Name, Neighbourhood ID, Neighbourhood, Ward, Assessed Value, Tax Class, Garage, Assessment Class 1, Assessment Class 2, Assessment Class 3, Assessment Class % 1, Assessment Class % 2, Assessment Class % 3, Latitude, Longitude, Point Location]
# Index: []

# %%
# let's create a better address by creating a new column on our dataframe
top_6_most_expensive["Property Address"] = top_6_most_expensive["House Number"].astype('str') \
        + " " + top_6_most_expensive["Street Name"].astype('str')
# note \  # continues next line
# note if you scroll to the end here you get the column that we've created (that's on the head)
top_6_most_expensive.head()
# Out:
#         Account Number Suite  House Number         Street Name  \
# 48426         10884511   NaN        9323.0      101A AVENUE NW
# 16746         11140992   NaN         605.0        23 AVENUE NW
# 313663         1113612   NaN        9131.0       231 STREET NW
# 247884        10845148   NaN       17311.0  MERIDIAN STREET NE
# 124777         1110303   NaN        3021.0  WINTERBURN ROAD NW
#
#         Neighbourhood ID Neighbourhood           Ward  Assessed Value  \
# 48426             1020.0  BOYLE STREET      O-day'min        13797500
# 16746             6445.0         ASTER     Sspomitapi        11986500
# 313663            4750.0     ROSENTHAL    Nakota Isga         9664500
# 247884            2671.0       MARQUIS           Dene         8793000
# 124777            4462.0      EDGEMONT  sipiwiyiniwak         8241500
#
#           Tax Class Garage Assessment Class 1 Assessment Class 2  \
# 48426   Residential      N        RESIDENTIAL        RESIDENTIAL
# 16746   Residential      Y        RESIDENTIAL        RESIDENTIAL
# 313663  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 247884  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 124777  Residential      Y        RESIDENTIAL        RESIDENTIAL
#
#        Assessment Class 3  Assessment Class % 1  Assessment Class % 2  \
# 48426                 NaN                    81                  19.0
# 16746            FARMLAND                    88                  10.0
# 313663         COMMERCIAL                    79                  20.0
# 247884         COMMERCIAL                    91                   8.0
# 124777         COMMERCIAL                    87                  10.0
#
#         Assessment Class % 3   Latitude   Longitude  \
# 48426                    NaN  53.544464 -113.476520
# 16746                    1.0  53.450272 -113.354457
# 313663                   1.0  53.524741 -113.709677
# 247884                   1.0  53.634177 -113.337959
# 124777                   3.0  53.462645 -113.682574
#
#                                         Point Location  \
# 48426    POINT (-113.47651960567521 53.54446435818227)
# 16746   POINT (-113.35445723560179 53.450272230472194)
# 313663   POINT (-113.70967688256843 53.52474058872421)
# 247884     POINT (-113.33795877058921 53.634176910731)
# 124777  POINT (-113.68257370485546 53.462644612185514)
#
#                   Property Address
# 48426        9323.0 101A AVENUE NW
# 16746           605.0 23 AVENUE NW
# 313663        9131.0 231 STREET NW
# 247884  17311.0 MERIDIAN STREET NE
# 124777   3021.0 WINTERBURN ROAD NW

# %%
# matplotlib

plt.figure(figsize=(10,6))
plt.bar(top_6_most_expensive["Property Address"], top_6_most_expensive["Assessed Value"])
plt.xlabel("Property Address")
plt.ylabel("Assessed Value")
plt.title("Top 6 most expensive Residential properties in Edmonton")
plt.xticks(rotation=45, ha='right')
plt.show() # this is goign to show the chart.

# %%
# lets' see what kind of tax classes there so that we know what's going on here.
# Out:
#         Account Number Suite  House Number         Street Name  \
# 48426         10884511   NaN        9323.0      101A AVENUE NW
# 16746         11140992   NaN         605.0        23 AVENUE NW
# 313663         1113612   NaN        9131.0       231 STREET NW
# 247884        10845148   NaN       17311.0  MERIDIAN STREET NE
# 124777         1110303   NaN        3021.0  WINTERBURN ROAD NW
# ...                ...   ...           ...                 ...
# 129027        10884622   NaN        9110.0       197 STREET SW
# 128938        10885102   NaN        1415.0        41 AVENUE SW
# 129038        10884667   NaN       21110.0        89 AVENUE SW
# 128940        10885104   NaN         915.0        41 AVENUE SW
# 129069        10884880   NaN        6220.0       200 STREET SW
#
#         Neighbourhood ID        Neighbourhood           Ward  Assessed Value  \
# 48426             1020.0         BOYLE STREET      O-day'min        13797500
# 16746             6445.0                ASTER     Sspomitapi        11986500
# 313663            4750.0            ROSENTHAL    Nakota Isga         9664500
# 247884            2671.0              MARQUIS           Dene         8793000
# 124777            4462.0             EDGEMONT  sipiwiyiniwak         8241500
# ...                  ...                  ...            ...             ...
# 129027            8888.0  EDMONTON SOUTH WEST      pihêsiwin          414500
# 128938            8886.0  EDMONTON SOUTH EAST     Sspomitapi          407500
# 129038            8888.0  EDMONTON SOUTH WEST      pihêsiwin          398000
# 128940            8886.0  EDMONTON SOUTH EAST     Sspomitapi          376000
# 129069            8888.0  EDMONTON SOUTH WEST      pihêsiwin           88000
#
#           Tax Class Garage Assessment Class 1 Assessment Class 2  \
# 48426   Residential      N        RESIDENTIAL        RESIDENTIAL
# 16746   Residential      Y        RESIDENTIAL        RESIDENTIAL
# 313663  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 247884  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 124777  Residential      Y        RESIDENTIAL        RESIDENTIAL
# ...             ...    ...                ...                ...
# 129027  Residential      N        RESIDENTIAL        RESIDENTIAL
# 128938  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 129038  Residential      Y        RESIDENTIAL        RESIDENTIAL
# 128940  Residential      N        RESIDENTIAL        RESIDENTIAL
# 129069  Residential      N        RESIDENTIAL        RESIDENTIAL
#
#        Assessment Class 3  Assessment Class % 1  Assessment Class % 2  \
# 48426                 NaN                    81                  19.0
# 16746            FARMLAND                    88                  10.0
# 313663         COMMERCIAL                    79                  20.0
# 247884         COMMERCIAL                    91                   8.0
# 124777         COMMERCIAL                    87                  10.0
# ...                   ...                   ...                   ...
# 129027        RESIDENTIAL                    74                  16.0
# 128938           FARMLAND                    98                   1.0
# 129038           FARMLAND                    81                  13.0
# 128940           FARMLAND                    98                   1.0
# 129069           FARMLAND                    88                  11.0
#
#         Assessment Class % 3   Latitude   Longitude  \
# 48426                    NaN  53.544464 -113.476520
# 16746                    1.0  53.450272 -113.354457
# 313663                   1.0  53.524741 -113.709677
# 247884                   1.0  53.634177 -113.337959
# 124777                   3.0  53.462645 -113.682574
# ...                      ...        ...         ...
# 129027                   5.0  53.348698 -113.662522
# 128938                   1.0  53.393335 -113.362587
# 129038                   6.0  53.355978 -113.680581
# 128940                   1.0  53.393328 -113.357886
# 129069                   1.0  53.376783 -113.665226
#
#                                         Point Location
# 48426    POINT (-113.47651960567521 53.54446435818227)
# 16746   POINT (-113.35445723560179 53.450272230472194)
# 313663   POINT (-113.70967688256843 53.52474058872421)
# 247884     POINT (-113.33795877058921 53.634176910731)
# 124777  POINT (-113.68257370485546 53.462644612185514)
# ...                                                ...
# 129027  POINT (-113.66252162829127 53.348698442553186)
# 128938  POINT (-113.36258711226662 53.393334666660884)
# 129038   POINT (-113.68058058651128 53.35597754671154)
# 128940   POINT (-113.35788595838159 53.39332766030811)
# 129069   POINT (-113.66522626845448 53.37678301001816)
#
# [143 rows x 19 columns]
